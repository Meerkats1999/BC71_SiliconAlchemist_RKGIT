# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
dfRegular = pd.read_csv('regular.csv', header=None)
dfSpeed = pd.read_csv('speedboy.csv', header=None)
dfGadda = pd.read_csv('gadda.csv', header=None)

# %%
time = np.arange(30)

# %%
row = np.array(dfRegular.iloc[0])
row = row[slice(0,30)]

row2 = np.array(dfSpeed.iloc[1])
row2 = row2[slice(0,30)]

row3 = np.array(dfGadda.iloc[0])
row3 = row3[slice(0,30)]

# %%
plt.plot(time,row,'r')
plt.plot(time,row2,'g')
plt.plot(time,row3,'b')

# %%
row = np.array(df.iloc[2])

# %%
plt.plot(time,row)

# %%
row = np.array(df.iloc[3])
plt.plot(time,row)

# %%
row = np.array(df.iloc[4])
plt.plot(time,row)

# %%
row = np.array(df.iloc[5])
plt.plot(time,row)

# %%
row = np.array(df.iloc[3])
plt.plot(time,row)

# %%
row = np.array(df.iloc[8])
plt.plot(time,row)

# %%
row = np.array(df.iloc[9])
plt.plot(time,row)

# %%
row = np.array(df.iloc[10])
plt.plot(time,row)

# %%
row = np.array(df.iloc[11])
plt.plot(time,row)

# %%
row = np.array(df.iloc[12])
plt.plot(time,row)

# %%
row = np.array(df.iloc[13])
plt.plot(time,row)

# %%
row = np.array(df.iloc[14])
plt.plot(time,row)

# %%
row = np.array(df.iloc[9])
plt.plot(row,time)

# %%
plt.scatter(time,row)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
